# %% [markdown]
# # Imports

# %%
#importing json and api login
import pandas as pd
import json
with open(r"\Users\camer\OneDrive\Documents\GitHub\dojo-env-setup\.secret\yelp_api.json") as f:
    login = json.load(f)
    
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
#importing yelp api
from yelpapi import YelpAPI
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %% [markdown]
# # First Yelp DF

# %%
#searching Boston Sushi in API
sushi = yelp_api.search_query(location='Greenville, SC',
                                       term='sushi',
                               offset = 20)
print(type(sushi))
sushi.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %%
#creating dataframe for boston sushi 
bostonsushi = pd.DataFrame(sushi['businesses'])
bostonsushi.head()
# Out:
#                        id                                            alias  \
# 0  vILtQZOAP_LqkV_BB4e0cQ                chef-21-sushi-burger-simpsonville
# 1  HlMRxvnD7jC6uMUYZCsDCg  tsunami-japanese-sushi-bar-and-grill-greenville
# 2  pCpt-b8_ashf7-lVwO8uBQ           zen-ramen-and-sushi-burrito-greenville
# 3  Cwpuu08FMJvSn5Vjsb590g                          bento-boys-greenville-8
# 4  L4GBV2rBF-NkRRXxdOHtpQ                 menkoi-noodle-house-greenville-3
#
#                                    name  \
# 0                  Chef 21 Sushi Burger
# 1  Tsunami Japanese Sushi Bar and Grill
# 2           Zen Ramen and Sushi Burrito
# 3                            Bento Boys
# 4                   Menkoi Noodle House
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/BXtxx2...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/ijTJAV...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/9Zooyi...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/U1qiI5...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/sO0VQR...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/chef-21-sushi-burger-...            57
# 1  https://www.yelp.com/biz/tsunami-japanese-sush...           123
# 2  https://www.yelp.com/biz/zen-ramen-and-sushi-b...            31
# 3  https://www.yelp.com/biz/bento-boys-greenville...            62
# 4  https://www.yelp.com/biz/menkoi-noodle-house-g...           180
#
#                                           categories  rating  \
# 0  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 1  [{'alias': 'japanese', 'title': 'Japanese'}, {...     3.5
# 2  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 3  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 4  [{'alias': 'ramen', 'title': 'Ramen'}, {'alias...     4.5
#
#                                          coordinates        transactions  \
# 0   {'latitude': 34.706319, 'longitude': -82.255358}  [delivery, pickup]
# 1     {'latitude': 34.85197, 'longitude': -82.39704}  [delivery, pickup]
# 2  {'latitude': 34.8208868730206, 'longitude': -8...          [delivery]
# 3  {'latitude': 34.8721237, 'longitude': -82.3587...  [delivery, pickup]
# 4    {'latitude': 34.85365, 'longitude': -82.398078}          [delivery]
#
#                                             location         phone  \
# 0  {'address1': '699 Fairview Rd', 'address2': No...  +18646882198
# 1  {'address1': '106 E North St', 'address2': '',...  +18644671055
# 2  {'address1': '1939-B Woodruff Rd', 'address2':...  +18646094066
# 3  {'address1': '1170 N Pleasantburg Dr', 'addres...  +18645201799
# 4  {'address1': '241 N Main St', 'address2': '', ...  +18643739233
#
#     display_phone      distance price
# 0  (864) 688-2198  18273.754985   NaN
# 1  (864) 467-1055   3633.796422    $$
# 2  (864) 609-4066   9067.405601   NaN
# 3  (864) 520-1799   2762.718538    $$
# 4  (864) 373-9233   3751.698214     $

# %%
#checking total
sushi['total']
# Out:
# 100

# %% [markdown]
# # Second Yelp DF

# %%
#creating second dataframe
sushi_0 = yelp_api.search_query(location='Greenville, SC',
                                       term='Sushi')
print(type(sushi_0))
sushi_0.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %%
nysushi = pd.DataFrame(sushi_0['businesses'])
nysushi.head()
# Out:
#                        id                                      alias  \
# 0  zG_XOAFi9Y560WJ1RvghBw  sushi-masa-japanese-restaurant-greenville
# 1  RGRk1ioORwm_FIX8PM732Q                      konnichiwa-greenville
# 2  babpQQHQSGjVxS1Li7Q2lA           otto-izakaya-downtown-greenville
# 3  VU0mq_4iDCZ3w1pDcbGiuQ                    love-sushi-greenville-4
# 4  7cJxOV-ANX1qLThK3yV96w                  otto-izakaya-greenville-4
#
#                              name  \
# 0  Sushi-Masa Japanese Restaurant
# 1                      Konnichiwa
# 2         Otto Izakaya - Downtown
# 3                      Love Sushi
# 4                    Otto Izakaya
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/zsRavZ...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/p47H0_...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/E9pMtT...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/zHiqdu...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/VOJsxi...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/sushi-masa-japanese-r...           146
# 1  https://www.yelp.com/biz/konnichiwa-greenville...            33
# 2  https://www.yelp.com/biz/otto-izakaya-downtown...           141
# 3  https://www.yelp.com/biz/love-sushi-greenville...            16
# 4  https://www.yelp.com/biz/otto-izakaya-greenvil...           409
#
#                                           categories  rating  \
# 0        [{'alias': 'sushi', 'title': 'Sushi Bars'}]     4.5
# 1  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 2  [{'alias': 'izakaya', 'title': 'Izakaya'}, {'a...     4.0
# 3       [{'alias': 'japanese', 'title': 'Japanese'}]     4.5
# 4  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
#
#                                          coordinates  \
# 0  {'latitude': 34.8512725830078, 'longitude': -8...
# 1  {'latitude': 34.845952342825115, 'longitude': ...
# 2       {'latitude': 34.84428, 'longitude': -82.406}
# 3     {'latitude': 34.82095, 'longitude': -82.25788}
# 4  {'latitude': 34.8228218820722, 'longitude': -8...
#
#                          transactions price  \
# 0                          [delivery]    $$
# 1                                  []   NaN
# 2  [delivery, restaurant_reservation]    $$
# 3                                  []   NaN
# 4                          [delivery]    $$
#
#                                             location         phone  \
# 0  {'address1': '8590 Pelham Rd', 'address2': 'St...  +18642882227
# 1  {'address1': '101 Falls Park Dr', 'address2': ...  +18642524436
# 2  {'address1': '802 S Main St', 'address2': '', ...  +18645685880
# 3  {'address1': '2131 Woodruff Rd', 'address2': '...  +18646756360
# 4  {'address1': '15 Market Point Dr', 'address2':...  +18645688009
#
#     display_phone      distance
# 0  (864) 288-2227  11481.830881
# 1  (864) 252-4436   4184.255183
# 2  (864) 568-5880   4427.933494
# 3  (864) 675-6360   9540.226675
# 4  (864) 568-8009   5933.485357

# %% [markdown]
# # Concatenate DFs

# %%
bostonsushi.head()
# Out:
#                        id                                            alias  \
# 0  vILtQZOAP_LqkV_BB4e0cQ                chef-21-sushi-burger-simpsonville
# 1  HlMRxvnD7jC6uMUYZCsDCg  tsunami-japanese-sushi-bar-and-grill-greenville
# 2  pCpt-b8_ashf7-lVwO8uBQ           zen-ramen-and-sushi-burrito-greenville
# 3  Cwpuu08FMJvSn5Vjsb590g                          bento-boys-greenville-8
# 4  L4GBV2rBF-NkRRXxdOHtpQ                 menkoi-noodle-house-greenville-3
#
#                                    name  \
# 0                  Chef 21 Sushi Burger
# 1  Tsunami Japanese Sushi Bar and Grill
# 2           Zen Ramen and Sushi Burrito
# 3                            Bento Boys
# 4                   Menkoi Noodle House
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/BXtxx2...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/ijTJAV...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/9Zooyi...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/U1qiI5...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/sO0VQR...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/chef-21-sushi-burger-...            57
# 1  https://www.yelp.com/biz/tsunami-japanese-sush...           123
# 2  https://www.yelp.com/biz/zen-ramen-and-sushi-b...            31
# 3  https://www.yelp.com/biz/bento-boys-greenville...            62
# 4  https://www.yelp.com/biz/menkoi-noodle-house-g...           180
#
#                                           categories  rating  \
# 0  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 1  [{'alias': 'japanese', 'title': 'Japanese'}, {...     3.5
# 2  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.5
# 3  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
# 4  [{'alias': 'ramen', 'title': 'Ramen'}, {'alias...     4.5
#
#                                          coordinates        transactions  \
# 0   {'latitude': 34.706319, 'longitude': -82.255358}  [delivery, pickup]
# 1     {'latitude': 34.85197, 'longitude': -82.39704}  [delivery, pickup]
# 2  {'latitude': 34.8208868730206, 'longitude': -8...          [delivery]
# 3  {'latitude': 34.8721237, 'longitude': -82.3587...  [delivery, pickup]
# 4    {'latitude': 34.85365, 'longitude': -82.398078}          [delivery]
#
#                                             location         phone  \
# 0  {'address1': '699 Fairview Rd', 'address2': No...  +18646882198
# 1  {'address1': '106 E North St', 'address2': '',...  +18644671055
# 2  {'address1': '1939-B Woodruff Rd', 'address2':...  +18646094066
# 3  {'address1': '1170 N Pleasantburg Dr', 'addres...  +18645201799
# 4  {'address1': '241 N Main St', 'address2': '', ...  +18643739233
#
#     display_phone      distance price
# 0  (864) 688-2198  18273.754985   NaN
# 1  (864) 467-1055   3633.796422    $$
# 2  (864) 609-4066   9067.405601   NaN
# 3  (864) 520-1799   2762.718538    $$
# 4  (864) 373-9233   3751.698214     $

# %%
nysushi.head()
# Out:
#                        id                                      alias  \
# 0  zG_XOAFi9Y560WJ1RvghBw  sushi-masa-japanese-restaurant-greenville
# 1  RGRk1ioORwm_FIX8PM732Q                      konnichiwa-greenville
# 2  babpQQHQSGjVxS1Li7Q2lA           otto-izakaya-downtown-greenville
# 3  VU0mq_4iDCZ3w1pDcbGiuQ                    love-sushi-greenville-4
# 4  7cJxOV-ANX1qLThK3yV96w                  otto-izakaya-greenville-4
#
#                              name  \
# 0  Sushi-Masa Japanese Restaurant
# 1                      Konnichiwa
# 2         Otto Izakaya - Downtown
# 3                      Love Sushi
# 4                    Otto Izakaya
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/zsRavZ...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/p47H0_...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/E9pMtT...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/zHiqdu...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/VOJsxi...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/sushi-masa-japanese-r...           146
# 1  https://www.yelp.com/biz/konnichiwa-greenville...            33
# 2  https://www.yelp.com/biz/otto-izakaya-downtown...           141
# 3  https://www.yelp.com/biz/love-sushi-greenville...            16
# 4  https://www.yelp.com/biz/otto-izakaya-greenvil...           409
#
#                                           categories  rating  \
# 0        [{'alias': 'sushi', 'title': 'Sushi Bars'}]     4.5
# 1  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 2  [{'alias': 'izakaya', 'title': 'Izakaya'}, {'a...     4.0
# 3       [{'alias': 'japanese', 'title': 'Japanese'}]     4.5
# 4  [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.0
#
#                                          coordinates  \
# 0  {'latitude': 34.8512725830078, 'longitude': -8...
# 1  {'latitude': 34.845952342825115, 'longitude': ...
# 2       {'latitude': 34.84428, 'longitude': -82.406}
# 3     {'latitude': 34.82095, 'longitude': -82.25788}
# 4  {'latitude': 34.8228218820722, 'longitude': -8...
#
#                          transactions price  \
# 0                          [delivery]    $$
# 1                                  []   NaN
# 2  [delivery, restaurant_reservation]    $$
# 3                                  []   NaN
# 4                          [delivery]    $$
#
#                                             location         phone  \
# 0  {'address1': '8590 Pelham Rd', 'address2': 'St...  +18642882227
# 1  {'address1': '101 Falls Park Dr', 'address2': ...  +18642524436
# 2  {'address1': '802 S Main St', 'address2': '', ...  +18645685880
# 3  {'address1': '2131 Woodruff Rd', 'address2': '...  +18646756360
# 4  {'address1': '15 Market Point Dr', 'address2':...  +18645688009
#
#     display_phone      distance
# 0  (864) 288-2227  11481.830881
# 1  (864) 252-4436   4184.255183
# 2  (864) 568-5880   4427.933494
# 3  (864) 675-6360   9540.226675
# 4  (864) 568-8009   5933.485357

# %%
#combining dataframes
#allsushi= pd.concat(['bostonsushi', 'nysushi'],
                   # ignore_index=True)

# %%
#now concatenate all pages
#all_sushi = pd.concat([sushi0, sushi20],
                     # ignore_index=True)
#display(all_sushi.head(3), all_sushi.tail(3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [11], line 2
#       1 #now concatenate all pages
# ----> 2 all_sushi = pd.concat([sushi0, sushi20],
#       3                       ignore_index=True)
#       4 display(all_sushi.head(3), all_sushi.tail(3))
#
# NameError: name 'sushi0' is not defined

# %%
#display(allsushi.head(3), allsushi.tail(3))

# %%
sushi_0 = yelp_api.search_query(location='Greenville, SC',
                                       term='Sushi')
type(sushi_0)
sushi_0.keys()

sushi0 = pd.DataFrame(sushi_0['businesses'])
sushi0.head(2)

sushi_0['total']

#Students are only asked to do the first two pages. Notice the offset in the code below is set to 20

# 92 will require 5 pages
# The assignment only asks for two pages
sushi_20 = yelp_api.search_query(location='Greenville, SC',
                                       term='sushi',
                               offset = 20)

sushi20 = pd.DataFrame(sushi_20['businesses'])
sushi20.head(2)

#now concatenate all pages
all_sushi = pd.concat([sushi0, sushi20],
                      ignore_index=True)
display(all_sushi.head(3), all_sushi.tail(3))
# Out:
#                        id                                      alias  \
# 0  zG_XOAFi9Y560WJ1RvghBw  sushi-masa-japanese-restaurant-greenville
# 1  RGRk1ioORwm_FIX8PM732Q                      konnichiwa-greenville
# 2  babpQQHQSGjVxS1Li7Q2lA           otto-izakaya-downtown-greenville
#
#                              name  \
# 0  Sushi-Masa Japanese Restaurant
# 1                      Konnichiwa
# 2         Otto Izakaya - Downtown
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/zsRavZ...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/p47H0_...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/E9pMtT...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/sushi-masa-japanese-r...           146
# 1  https://www.yelp.com/biz/konnichiwa-greenville...            33
# 2  https://www.yelp.com/biz/otto-izakaya-downtown...           141
#
#                                           categories  rating  \
# 0        [{'alias': 'sushi', 'title': 'Sushi Bars'}]     4.5
# 1  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 2  [{'alias': 'izakaya', 'title': 'Izakaya'}, {'a...     4.0
#
#                                          coordinates  \
# 0  {'latitude': 34.8512725830078, 'longitude': -8...
# 1  {'latitude': 34.845952342825115, 'longitude': ...
# 2       {'latitude': 34.84428, 'longitude': -82.406}
#
#                          transactions price  \
# 0                          [delivery]    $$
# 1                                  []   NaN
# 2  [delivery, restaurant_reservation]    $$
#
#                                             location         phone  \
# 0  {'address1': '8590 Pelham Rd', 'address2': 'St...  +18642882227
# 1  {'address1': '101 Falls Park Dr', 'address2': ...  +18642524436
# 2  {'address1': '802 S Main St', 'address2': '', ...  +18645685880
#
#     display_phone      distance
# 0  (864) 288-2227  11481.830881
# 1  (864) 252-4436   4184.255183
# 2  (864) 568-5880   4427.933494
#                         id                                   alias  \
# 37  fjpQXddk1h5vGtS9kLjoJg          red-bowl-greenville-greenville
# 38  Mh9a3Zc78w46m02fCgVY-A  asia-pacific-super-market-greenville-3
# 39  msWJkhRnS5rgYnwn8OoM4g              kanpai-of-toyko-greenville
#
#                          name  \
# 37      Red Bowl - Greenville
# 38  Asia Pacific Super Market
# 39            Kanpai of Toyko
#
#                                             image_url  is_closed  \
# 37  https://s3-media2.fl.yelpcdn.com/bphoto/9uBE_w...      False
# 38  https://s3-media1.fl.yelpcdn.com/bphoto/C0McWe...      False
# 39  https://s3-media1.fl.yelpcdn.com/bphoto/RvJy17...      False
#
#                                                   url  review_count  \
# 37  https://www.yelp.com/biz/red-bowl-greenville-g...           138
# 38  https://www.yelp.com/biz/asia-pacific-super-ma...           166
# 39  https://www.yelp.com/biz/kanpai-of-toyko-green...           124
#
#                                            categories  rating  \
# 37  [{'alias': 'japanese', 'title': 'Japanese'}, {...     3.0
# 38  [{'alias': 'intlgrocery', 'title': 'Internatio...     4.5
# 39  [{'alias': 'japanese', 'title': 'Japanese'}, {...     2.0
#
#                                           coordinates transactions price  \
# 37  {'latitude': 34.841634, 'longitude': -82.3633539}   [delivery]    $$
# 38     {'latitude': 34.85289, 'longitude': -82.35708}   [delivery]    $$
# 39  {'latitude': 34.8464317321777, 'longitude': -8...   [delivery]    $$
#
#                                              location         phone  \
# 37  {'address1': '27 S Pleasantburg Dr', 'address2...  +18642717977
# 38  {'address1': '420 N Pleasantburg Dr', 'address...  +18646031377
# 39  {'address1': '533 Haywood Rd', 'address2': '',...  +18642340334
#
#      display_phone     distance
# 37  (864) 271-7977   842.088788
# 38  (864) 603-1377   653.049027
# 39  (864) 234-0334  1531.255857
