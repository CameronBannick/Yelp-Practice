# %%
#importing json and api login
import pandas as pd
import json
with open(r"\Users\camer\OneDrive\Documents\GitHub\dojo-env-setup\.secret\yelp_api.json") as f:
    login = json.load(f)
    
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
#importing yelp api
from yelpapi import YelpAPI
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %%
#searching crabcakes in API
results = yelp_api.search_query(location='Baltimore, MD',
                                term='Crab Cake',
                                offset=20)
print(type(results))
results.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %%
#creating crab cake dataframeb
crab_cake = pd.DataFrame(results['businesses'])
crab_cake.head()
# Out:
#                        id                                              alias  \
# 0  7lDhtcolamUZw6oP5V1ehw                           flash-crabcake-baltimore
# 1  pJuoa35eDPRXLf7kUbpMTg                             the-choptank-baltimore
# 2  1EH88Idp4v2pWorFt2U4Cw                   true-chesapeake-oyster-baltimore
# 3  UmXaCo_4O-nkvPN1bdfawQ  conrads-crabs-and-seafood-market-parkville-par...
# 4  TL34QOmDmMtJmsabvPLErg                       annabel-lee-tavern-baltimore
#
#                                           name  \
# 0                               Flash Crabcake
# 1                                 The Choptank
# 2                       True Chesapeake Oyster
# 3  Conrad's Crabs & Seafood Market - Parkville
# 4                           Annabel Lee Tavern
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/KrZ0tm...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/uUp93m...      False
# ...

# %%
#checking total
results['total']
# Out:
# 877

# %%
#creating second dataframe
sushi = yelp_api.search_query(location='Boston, MA',
                                    term='Sushi',
                                    offset=20)
print(type(sushi))
sushi.keys()
# Out:
# <class 'dict'>
# dict_keys(['businesses', 'total', 'region'])

# %%
sushi20 = pd.DataFrame(sushi['businesses'])
sushi20.head()
# Out:
#                        id                                           alias  \
# 0  n0NNUVwW-wEKc433oKZX5A              kura-revolving-sushi-bar-watertown
# 1  JO1aGVtB0TYtunc4Km_-Dg                                      koy-boston
# 2  GfuDpypk9ekc8OsMRTMJ0A                  north-end-fish-market-boston-3
# 3  qBDpPs3Wg7EmUI5XGeUEdA  fugakyu-japanese-cuisine-brookline-brookline-2
# 4  pNgDJTvALiSQvE6gK4b9MQ                         umami-omakase-cambridge
#
#                                    name  \
# 0              Kura Revolving Sushi Bar
# 1                                   Koy
# 2                 North End Fish Market
# 3  FuGaKyu Japanese Cuisine - Brookline
# 4                         Umami Omakase
#
#                                            image_url  is_closed  \
# 0  https://s3-media3.fl.yelpcdn.com/bphoto/X9ax2g...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/v0b4D2...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/BvuWok...      False
# ...

# %%
#combining dataframes
total_cc = pd.concat(['crab_cake', 'sushi20'],
                    ignore_index=True)
display(total_cc.head(3), total_cc.tail(3))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [12], line 2
#       1 #combining dataframes
# ----> 2 total_cc = pd.concat(['crab_cake ', 'sushi20'],
#       3                     ignore_index=True)
#       4 display(total_cc.head(3), total_cc.tail(3))
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\reshape\concat.py:347, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
# ...
